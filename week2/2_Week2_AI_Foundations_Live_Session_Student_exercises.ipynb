# %% [markdown]
# # Week 2: AI Foundations - Live Session
# ## From Secrets to Attention: Building Your AI Intuition
#
# **Student Exercises Notebook**
#
# Use this notebook to work through the same flow as the master notebook, but fill in the code cells yourself using the hints provided.

# %% [markdown]
# # Topic 1: Environment Variables & Secrets ??
#
# **Objective**: Learn why `.env` files matter, how to store secrets securely, and access them in code.

# %%
# Exercise 1: Load environment variables from .env
# Hints:
# - Use python-dotenv
# - Call load_dotenv() before reading variables
# - Read OPENAI_API_KEY with os.getenv(...)
# - Do not print the full key; mask it if you display it

# Your code here:

# %%
# Verify the API key is loaded (show only first and last few characters for security)
# Hints:
# - if openai_api_key: build masked_key from first ~10 and last ~10 characters
# - print a success message with the masked key, else print a not-found message

# Your code here:

# %% [markdown]
# ### Exercise: Create and check `TEST_SECRET`
#
# Set `TEST_SECRET` in your `.env` file, then write code to confirm whether it is available.

# %%
# Exercise 2: Check TEST_SECRET
# Hints:
# - os.getenv('TEST_SECRET')
# - Print whether the value exists
# - Optionally show a masked version, not the full secret

# Your code here:

# %% [markdown]
# ### Practice: Check multiple variables
#
# Try reading `OPENAI_API_KEY`, `HF_API_KEY`, and `LANGCHAIN_API_KEY`, then print whether each one is set.

# %%
# Exercise 3: Check several environment variables
# Hints:
# - Store the variable names in a list or dictionary
# - Loop through them and print Set / Not set
# - Keep the output simple and readable

# Your code here:

# %% [markdown]
# ---
# # Topic 2: OpenAI Library & LLM Integration ??
#
# **Objective**: Learn to use the OpenAI Python library to interact with LLMs via the Chat API.

# %%
# Exercise 4: Import OpenAI and prepare a client
# Hints:
# - Import OpenAI from the openai package
# - Initialize the client with your API key from the environment
# - Keep the setup in a reusable cell

# Your code here:

# %%
# Hints:
# - client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Your code here:

# %% [markdown]
# ## Chat API Fundamentals
#
# The Chat API uses `messages` with roles such as `system`, `user`, and `assistant`.

# %% [markdown]
# System - Role of the LLM <br>
# User Message - End users message <br>
# AI Message - Response that we get from the LLM is the AI Message <br>

# %% [markdown]
# Temperature controls how creative vs predictable the AI's outputs is?

# %% [markdown]
# Low Temperature (0-0.3) -> Deterministic (Highest probability words) <br>
# Medium Temperature (0.4-0.7) -> Balanced <br>
# High Temperature (0.8-1+) -> Randomness Increases <br>

# %%
# Exercise 5: Make your first chat call
# Hints:
# - Use model = 'gpt-4o-mini' or another available chat model
# - Pass a system message and a user message
# - Use a small max_tokens value for a short answer
# - Print the assistant response text and token usage if available

# Your code here:

# %%
# Hints:
# - print(response.choices[0].message.content)

# Your code here:

# %% [markdown]
# ### Temperature Exercise
#
# Try different temperature values such as `0.0`, `0.7`, and `1.5` and compare the outputs.

# %%
# Exercise 6: Compare responses at different temperatures
# Hints:
# - Loop over a few temperature values
# - Use the same prompt each time
# - Print the model response for each temperature

# Your code here:

# %%
# Hints:
# - call client.chat.completions.create(..., stream=True)
# - iterate over the stream; each chunk.choices[0].delta.content is a token piece
# - print each token as it arrives with end="", flush=True
# - accumulate the full response and print its length at the end

# Your code here:

# %% [markdown]
# ## System Prompt Demo
#
# Use a system prompt to change the assistant style or behavior.

# %%
# Exercise 7: Test different system prompts
# Hints:
# - Start with a simple system instruction like 'You are a strict teacher'
# - Compare it with a friendly or concise system prompt
# - Observe how the answer style changes

# Your code here:

# %% [markdown]
# ## Hallucinations
#
# Try prompts that ask for uncertain or future events, then observe how the model responds.

# %%
# Exercise 8: Explore hallucination-prone prompts
# Hints:
# - Ask a question that does not have a reliable factual answer
# - Observe how the model handles uncertainty
# - Discuss whether the answer is confident, cautious, or speculative

# Your code here:

# %%
# Hints:
# - print(response.choices[0].message.content)

# Your code here:

# %% [markdown]
# ## Interactive Input
#
# Write a small prompt that takes user input and sends it to the model.

# %%
# Exercise 9: Accept user input and send it to the model
# Hints:
# - Use input('Ask anything: ')
# - Send the user text as a message to the chat API
# - Print the assistant response

# Your code here:

# %% [markdown]
# ## Token Count Awareness
#
# Check the `usage` information returned by the API and note how many tokens were used.

# %%
# Exercise 10: Print token usage from the last response
# Hints:
# - Access the usage object on the response
# - Print total_tokens or the available token breakdown

# Your code here:

# %% [markdown]
# ## Part 2.5: Vision Capabilities
#
# Write a request that sends an image URL along with a text question.

# %%
# Exercise 11: Try an image analysis request
# Hints:
# - Use a vision-capable model
# - Provide both text and image_url content in the message
# - Keep the question short and direct
# - Wrap the call in try/except since public image URLs can fail to download

# Your code here:

# %% [markdown]
# ---
# # Topic 3: Tokenization Deep Dive ??
#
# **Objective**: Understand how LLMs break down text into tokens, count them, and estimate costs.

# %%
# Exercise 12: Load a tokenizer
# Hints:
# - Install tiktoken if needed
# - Load an encoding for a chat model
# - Confirm that the tokenizer is ready before encoding text

# Your code here:

# %%
# Exercise 13: Tokenize a sample sentence
# Hints:
# - Encode a short sentence
# - Print the token list and the token count
# - Decode the tokens back to text

# Your code here:

# %%
# Hints:
# - print(tokens)
# - print(len(tokens))

# Your code here:

# %%
# Hints:
# - decoded = encoding.decode(tokens)
# - print(decoded)

# Your code here:

# %% [markdown]
# ### Exercise: Tokenize your own sentence
#
# Pick any sentence, tokenize it, decode each token, and observe which words split into multiple tokens.

# %%
# Exercise 14: Tokenize custom text
# Hints:
# - Choose a sentence with a few uncommon words or emoji
# - Print each token decoded one by one
# - Find at least one word that splits into multiple tokens

# Your code here:

# %% [markdown]
# ### Cost Calculation
#
# Estimate how token count affects the cost of a longer piece of text.

# %%
# Exercise 15: Estimate cost from token count
# Hints:
# - Repeat a sample text many times to simulate a long document
# - Count tokens with your tokenizer
# - Multiply by model pricing per 1K tokens to estimate cost

# Your code here:

# %% [markdown]
# ---
# # Topic 4: Embeddings & Semantic Search ??
#
# **Objective**: Learn what embeddings are, how to create them, and build a simple semantic search.

# %%
# Exercise 16: Create embeddings for a few texts
# Hints:
# - Use a small list of 4 to 6 short texts
# - Call the embeddings endpoint for each text
# - Store the vectors in a list and inspect their dimension

# Your code here:

# %%
# Exercise 17: Compute cosine similarity
# Hints:
# - Use numpy dot product and vector norms
# - Compare two embeddings and print the similarity score
# - Notice how similar topics should get higher scores

# Your code here:

# %%
# Exercise 18: Visualize embeddings in 2D
# Hints:
# - Reduce the embeddings with PCA or another 2D method
# - Plot points with labels so the clusters are easy to see
# - Keep the visualization simple and readable

# Your code here:

# %%
# Exercise 19: Build semantic search
# Hints:
# - Embed the query text
# - Compare the query embedding with every document embedding
# - Rank the documents by similarity and print the results

# Your code here:

# %% [markdown]
# ### Exercise: Build your own semantic search
#
# Use your own document list, create embeddings, and try a query from a different topic.

# %%
# Exercise 20: Semantic search with your own documents
# Hints:
# - Define 5 to 10 short documents from mixed topics
# - Create embeddings for each document
# - Query with a sentence and print the ranked matches

# Your code here:

# %% [markdown]
# ---
# # Topic 5: Attention Mechanism Explained ??
#
# **Objective**: Understand how transformers focus on relevant parts of text using attention.

# %%
# Exercise 21: Visualize attention weights
# Hints:
# - Choose a sentence such as 'The cat sat on the mat'
# - Decide which words should receive higher attention for a chosen focus word
# - Print a simple bar visualization with text characters

# Your code here:

# %%
# Exercise 22: Break down Query-Key-Value
# Hints:
# - Explain Q as 'what am I looking for?'
# - Explain K as 'what am I?'
# - Explain V as 'what information do I hold?'
# - You can summarize the idea with a printed table or a comment block

# Your code here:

# %%
# Exercise 23: Implement scaled dot-product attention
# Hints:
# - Compute scores = Q @ K.T / sqrt(d_k)
# - Apply softmax row-wise to get weights
# - Multiply weights by V to get the output
# - Test the function on small NumPy arrays

# Your code here:

# %%
# Exercise 24: Visualize an attention pattern
# Hints:
# - Create a small attention matrix for a short sentence
# - Use symbols like ░, ▒, ▓, █ to represent intensity
# - Print the matrix in a readable grid format

# Your code here:

# %% [markdown]
# ### Final Exercise: Trace attention manually
#
# Choose a sentence, pick one focus word, and assign attention weights that sum to 1.0. Explain why certain words get higher or lower weights.

# %%
# Exercise 25: Manually trace attention for a sentence
# Hints:
# - Pick one focus word
# - Assign weights to each word in the sentence
# - Ensure the weights sum to 1.0
# - Print a simple bar chart using repeated characters

# Your code here:

# %% [markdown]
# ---
# # ?? Recap & Key Takeaways
#
# ## What We Covered
#
# | Topic | Key Concept | Real-World Use |
# |-------|-------------|----------------|
# | **.env & Secrets** | Store sensitive data outside code | Production deployments, security |
# | **OpenAI Library** | Chat API, functions, vision, streaming | Building AI applications |
# | **Tokenization** | Text ? numbers, counting for cost | API budgeting, context management |
# | **Embeddings** | Meaning ? vectors, semantic similarity | Search, recommendations, RAG |
# | **Attention** | Focus mechanism, Q?K?V mechanism | How transformers work |
#
# ## Next Steps
#
# 1. Week 3: Build your first LangChain application
# 2. Week 4: Implement memory and agents
# 3. Week 5+: RAG systems and production deployments
